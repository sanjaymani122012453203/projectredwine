# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
HN=pd.read_csv("C:/Users/ADMIN/Downloads/winequality-red (1).csv")

# %%
HN
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
HN.shape
# Out:
# (1599, 12)

# %%
newdataset=HN.drop(['fixed acidity','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH',],axis=1)

# %%
newdataset
# Out:
#       volatile acidity  citric acid  residual sugar  sulphates  alcohol  \
# 0                0.700         0.00             1.9       0.56      9.4
# 1                0.880         0.00             2.6       0.68      9.8
# 2                0.760         0.04             2.3       0.65      9.8
# 3                0.280         0.56             1.9       0.58      9.8
# 4                0.700         0.00             1.9       0.56      9.4
# ...                ...          ...             ...        ...      ...
# 1594             0.600         0.08             2.0       0.58     10.5
# 1595             0.550         0.10             2.2       0.76     11.2
# 1596             0.510         0.13             2.3       0.75     11.0
# 1597             0.645         0.12             2.0       0.71     10.2
# 1598             0.310         0.47             3.6       0.66     11.0
#
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...

# %%
x=HN.iloc[:,0].values.reshape(-1,1)
y=HN.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[7.4],
#        [7.8],
#        [7.8],
#        ...,
#        [6.3],
#        [5.9],
#        [6. ]])

# %%
x=HN.iloc[:,0].values.reshape(-1,1)
y=HN.iloc[:,-1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('citric acid')
pt.ylabel('quality')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
x_test.shape
# Out:
# (800, 1)

# %%
y_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
y_test.shape
# Out:
# (800, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[5.82508427],
#        [5.6480444 ],
#        [5.71361472],
#        [5.78574208],
#        [5.91688272],
#        [5.65460143],
#        [5.72672879],
#        [5.72672879],
#        [5.69394362],
#        [5.58247408],
#        [5.68082956],
#        [5.74639988],
#        [5.73328582],
#        [5.4447764 ],
#        [5.47100453],
#        [5.60870221],
#        [5.65460143],
#        [5.73328582],
#        [5.53001782],
#        [5.60214517],
#        [5.58247408],
#        [5.70705769],
#        [5.60870221],
#        [5.51034672],
#        [5.53657485],
#        [5.62181627],
#        [5.70705769],
#        [5.59558814],
#        [5.68082956],
#        [5.45133343],
#        [5.78574208],
#        [5.66115846],
#        [5.56936001],
#        [5.60214517],
#        [5.54968892],
#        [5.79885614],
#        [5.52346079],
#        [5.56936001],
#        [5.50378969],
#        [5.59558814],
#        [5.67427253],
#        [5.58903111],
#        [5.4447764 ],
# ...

# %%
check=pd.DataFrame(x_test,columns=['quality'])

# %%
check['predicted']=y_predict

# %%
check
# Out:
#      quality  predicted
# 0       10.8   5.825084
# 1        8.1   5.648044
# 2        9.1   5.713615
# 3       10.2   5.785742
# 4       12.2   5.916883
# ..       ...        ...
# 795      7.1   5.582474
# 796      8.7   5.687387
# 797      7.2   5.589031
# 798      7.3   5.595588
# 799      9.4   5.733286
#
# [800 rows x 2 columns]

# %%
plt.scatter(x,y,color='red')
plt.show()

# %%
plt.scatter(x,y,color='red')
plt.plot(x_test,y_predict,color='green')
plt.show()

# %%
import seaborn as sns

# %%
import numpy as np

# %%
sns.set(style='darkgrid')

# %%
random=np.random.randn(100)

# %%
sns.distplot(random)
# Out:
# <AxesSubplot:ylabel='Density'>
